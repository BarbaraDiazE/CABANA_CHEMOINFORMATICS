# %% [markdown]
# For this project we will attempt to use KMeans Clustering to cluster Compounds in 3 groups, FDA,  Biofacquim and AFRODB
#
# note, we have the Library labels for this data set, but we will NOT use them for the KMeans clustering algorithm (unsupervised learning algorithm).
#
# In this case we will use the labels to try to get an idea of how well the algorithm performed, but you won't usually do this for Kmeans
#
# so the classification report and confusion matrix at the end of this project, don't truly make sense in a real world setting!

# %% [markdown]
# ## Import Libraries
#
# ** Import the libraries you usually use for data analysis.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get the Data

# %%
Data = pd.read_csv("Data_cluster.csv",index_col=0)

# %%
Data.columns
# Out:
# Index(['ID Database', 'Name', 'SMILES', 'HBA', 'HBD', 'RB', 'LogP', 'TPSA',
#        'MW', 'Heavy Atom', 'Ring Count', 'Fraction CSP3', 'subLibrary',
#        'Library', 'Target'],
#       dtype='object')

# %%
#Select descriptors to train model (Numerical Data)
features = ['HBA', 'HBD', 'RB', 'LogP', 'TPSA', 'MW', 
            'Heavy Atom', 'Ring Count', 'Fraction CSP3']

# %%
#Create a new data frame with numerical data
df = Data[features]

# %%
#df.info()

# %%
#df.describe()

# %% [markdown]
# ## EDA
#
# It's time to create some data visualizations!

# %%
sns.heatmap(df.corr())

# %%
sns.set_style('whitegrid')
sns.lmplot('LogP','MW',data=Data, hue='Library',
           palette='cool',size=6,aspect=1,fit_reg=False)
# Out:
# /home/babs/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.lmplot('TPSA','MW',data=Data, hue='Library',
           palette='cool',size=6,aspect=1,fit_reg=False)
# Out:
# /home/babs/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.FacetGrid(Data,hue="Library",palette='cool',size=6,aspect=2)
g = g.map(plt.hist,'MW',bins=20,alpha=0.7)
# Out:
# /home/babs/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Create a similar histogram for the Grad.Rate column.**

# %%
sns.set_style('darkgrid')
g = sns.FacetGrid(Data,hue="Library",palette='cool',size=6,aspect=2)
g = g.map(plt.hist,'TPSA',bins=20,alpha=0.7)
# Out:
# /home/babs/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('darkgrid')
g = sns.FacetGrid(Data,hue="Library",palette='cool',size=6,aspect=2)
g = g.map(plt.hist,'Heavy Atom',bins=20,alpha=0.7)
# Out:
# /home/babs/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# """K Means Cluster Creation """

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ** Create an instance of a K Means model with 2 clusters.**

# %%
kmeans = KMeans(n_clusters=3)

# %% [markdown]
# **Fit the model to all the data except for the Private label.**

# %%
kmeans.fit(df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ** What are the cluster center vectors?**

# %%
kmeans.cluster_centers_
# Out:
# array([[   3.43828892,    1.55820477,    2.85624123,    2.10873146,
#           58.47526648,  246.1309059 ,   17.5056101 ,   17.5056101 ,
#           17.5056101 ],
#        [  25.4       ,   11.65714286,   26.77142857,    1.71301429,
#          384.81      , 1236.99648571,   85.8       ,   85.8       ,
#           85.8       ],
#        [   5.84070796,    2.2614642 ,    5.26307321,    4.09003057,
#           91.84766693,  438.04651128,   31.34111022,   31.34111022,
#           31.34111022]])

# %%
kmeans
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.labels_
# Out:
# array([1, 1, 1, ..., 2, 0, 0], dtype=int32)

# %% [markdown]
# ## Evaluation
#
# There is no perfect way to evaluate clustering if you don't have the labels, however since this is just an exercise, we do have the labels, so we take advantage of this to evaluate our clusters, keep in mind, you usually won't have this luxury in the real world.
#
# ** Create a new column for df called 'Cluster', which is:
#     Afro -> 0,
#     Biofacquim -> 1,
#     FDA -> 2,

# %%
#Add predictions to Data
Data['Cluster'] = kmeans.labels_

# %%
#Plot scatter plots again
#Now hue is "Cluster" (predicted result)
sns.set_style('whitegrid')
sns.lmplot('LogP','MW',data=Data, hue='Cluster',
           palette='cool',size=6,aspect=1,fit_reg=False)
# Out:
# /home/babs/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.lmplot('TPSA','MW',data=Data, hue='Cluster',
           palette='cool',size=6,aspect=1,fit_reg=False)
# Out:
# /home/babs/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# In the last plot patters are similar,
# we can say that cluster predictions is not so bad

# %% [markdown]
# ** Create a confusion matrix and classification report to see how well the Kmeans clustering worked without being given any labels.**

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(Data['Target'],kmeans.labels_))
print(classification_report(Data['Target'],kmeans.labels_))
# Out:
# [[  0   0   0   0]
#  [331   6 617   0]
#  [213  29 181   0]
#  [882   0 445   0]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.17      0.01      0.01       954
#            2       0.15      0.43      0.22       423
#            3       0.00      0.00      0.00      1327
#
#    micro avg       0.07      0.07      0.07      2704
#    macro avg       0.08      0.11      0.06      2704
# weighted avg       0.08      0.07      0.04      2704
# /home/babs/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/babs/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/babs/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/babs/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/babs/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/babs/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
